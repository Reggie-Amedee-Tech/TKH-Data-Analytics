# %% [markdown]
# # Lab 09 — Choosing the Right Model: Complexity, Interpretability, and Generalization
#
# **Week:** 5
# **Day:** 1
# **Type:** Guided
# **Estimated time:** 45–55 minutes
# **Dataset:** Heart Disease (303 patients, 13 clinical features)
#
# ### Learning Objectives
# - Explain how model capacity determines the trade-off between training error and generalization
# - Identify when interpretability requirements constrain algorithm choice
# - Distinguish between model parameters (learned from data) and hyperparameters (set before training)
# - Apply the standard train/test split pattern to a real dataset
# - Recognize matrix multiplication as the core operation behind every linear model prediction
#
# ### Reference working sessions
# - `working-sessions/ml_concepts/12_model_complexity_and_capacity.ipynb`
# - `working-sessions/ml_concepts/13_interpretability_vs_complexity.ipynb`
# - `working-sessions/ml_concepts/14_parametric_vs_nonparametric_models.ipynb`
# - `working-sessions/ml_concepts/15_generalization_and_the_test_set.ipynb`
# - `working-sessions/ml_concepts/16_what_are_hyperparameters.ipynb`
# - `working-sessions/supervised/00_supervised_learning_overview.ipynb`
# - `working-sessions/math/linear_algebra/09_linear_algebra_in_ml.ipynb`
#
# ### A note before you start
# This is a guided lab. Each coding exercise has a scaffold with blanks — your job is to fill them in. Read every comment carefully before writing code. Run each cell after completing it to check your work.

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from tkh_utils import (
    PALETTE, FONT, base_layout,
    check_answer, make_answer_key, make_grading_summary,
    load_heart_disease,
)

_ak = make_answer_key({
    'q1': 'B',
    'q2': 'B',
    'q3': 'D',
    'q4': 'C',
})

# %% [markdown]
# ---
# ## Section A — Multiple Choice
#
# Fill in each answer variable with the letter of the best answer (A, B, C, or D).

# %%
# Q1 — You train a decision tree with no limit on max_depth.
# Given enough data and splits, what will the training error approach?
#
# A) The same error as the validation set — it generalizes as it memorizes
# B) Zero — the tree can keep splitting until every training point is
#    perfectly classified
# C) 50% — a tree without regularization settles at random-guess performance
# D) The irreducible Bayes error — there is always some noise no model can remove

q1_answer = "___"  # Replace with A, B, C, or D

assert q1_answer != "___", "Don't forget to fill in your answer!"
assert check_answer(q1_answer, _ak['q1']), \
    "Not quite — revisit working-sessions/ml_concepts/12_model_complexity_and_capacity.ipynb. " \
    "Drag the max_depth slider to its maximum and watch training accuracy."
print("\u2713 Question 1 correct!")

# %%
# Q2 — A hospital builds a model to recommend cancer treatment plans.
# Why might interpretability be the most important selection criterion,
# even if it means accepting slightly lower accuracy?
#
# A) Interpretable models always run faster on hospital hardware
# B) Regulations and patient safety standards may legally require
#    the model to explain its decisions
# C) Nonparametric models always need more data than hospitals can collect
# D) Neural networks are too slow for real-time treatment recommendations

q2_answer = "___"  # Replace with A, B, C, or D

assert q2_answer != "___", "Don't forget to fill in your answer!"
assert check_answer(q2_answer, _ak['q2']), \
    "Not quite — revisit working-sessions/ml_concepts/13_interpretability_vs_complexity.ipynb " \
    "and select the Healthcare domain from the dropdown."
print("\u2713 Question 2 correct!")

# %%
# Q3 — A nonparametric model (KNN, k=1) and a parametric model
# (logistic regression) are both trained on a dataset of 40 samples
# where the decision boundary is roughly linear. What would you most expect?
#
# A) KNN will generalize better — it makes no assumptions about the shape
# B) Both models will perform identically on this size of data
# C) KNN will train faster since it requires no optimization
# D) Logistic regression will generalize better — its linear assumption
#    matches the data, and 40 samples is too little for KNN to learn
#    local structure reliably

q3_answer = "___"  # Replace with A, B, C, or D

assert q3_answer != "___", "Don't forget to fill in your answer!"
assert check_answer(q3_answer, _ak['q3']), \
    "Not quite — revisit working-sessions/ml_concepts/14_parametric_vs_nonparametric_models.ipynb. " \
    "Set the sample size slider low and switch to linear data."
print("\u2713 Question 3 correct!")

# %%
# Q4 — A data scientist reports: 'I ran my model on the test set 20 times
# while tuning hyperparameters.' Why is this a problem?
#
# A) Running 20 evaluations is computationally wasteful — one is sufficient
# B) The test set should only be split once; running it multiple times
#    corrupts the split
# C) Each evaluation against the test set is a chance to select the
#    combination that happens to score best on that specific slice —
#    the reported score will be optimistic
# D) scikit-learn does not support multiple evaluations on the same test set

q4_answer = "___"  # Replace with A, B, C, or D

assert q4_answer != "___", "Don't forget to fill in your answer!"
assert check_answer(q4_answer, _ak['q4']), \
    "Not quite — revisit working-sessions/ml_concepts/15_generalization_and_the_test_set.ipynb"
print("\u2713 Question 4 correct!")

# %%
make_grading_summary([
    (q1_answer, _ak['q1'], "Q1: Model capacity and training error"),
    (q2_answer, _ak['q2'], "Q2: Interpretability in regulated contexts"),
    (q3_answer, _ak['q3'], "Q3: Parametric vs nonparametric on small data"),
    (q4_answer, _ak['q4'], "Q4: Test set discipline"),
], total=4)

# %% [markdown]
# ---
# ## Section B — Coding Exercises
#
# The exercises below build three fundamental skills you will use in every ML project: splitting data correctly, identifying what you control versus what the model learns, and understanding how predictions are computed as matrix operations.

# %% [markdown]
# ### B1 — Train/test split
#
# Every supervised learning pipeline starts with this exact step. The pattern below is the standard way to divide a dataset into training and test portions.

# %%
# B1 — Complete the train/test split
#
# Use train_test_split to divide the heart disease dataset:
#   - Hold out 20% of the data for testing
#   - Use random_state=42 so results are reproducible

X, y = load_heart_disease()

X_train, X_test, y_train, y_test = train_test_split(
    ___,              # YOUR CODE — the features matrix
    ___,              # YOUR CODE — the target vector
    test_size=___,    # YOUR CODE — hold out 20%
    random_state=___,  # YOUR CODE — set to 42
)

print(f"Training set : {X_train.shape[0]} samples, {X_train.shape[1]} features")
print(f"Test set     : {X_test.shape[0]} samples, {X_test.shape[1]} features")
print(f"Train labels : {y_train.shape[0]}")
print(f"Test labels  : {y_test.shape[0]}")

# --- checks ---
assert X_train.shape[0] + X_test.shape[0] == len(X), \
    "Training and test sets should together contain all 303 samples"
assert X_test.shape[0] in [60, 61], \
    "Test set should hold ~20% (~60-61 samples) — check test_size=0.2"
assert X_train.shape[1] == 13, \
    "Features should not change — each split should still have 13 columns"
assert y_train.shape[0] == X_train.shape[0], \
    "y_train must have one label per training sample"
print("\u2713 B1 complete!")

# %% [markdown]
# ### B2 — Parameters vs hyperparameters
#
# Every ML algorithm has two types of values: ones the model learns from data (parameters), and ones you set before training starts (hyperparameters). Knowing the difference tells you what you can tune and what you leave to the algorithm.

# %%
# B2 — Label each item as 'parameter' or 'hyperparameter'
#
# 'parameter'      — a value the model learns during .fit()
# 'hyperparameter' — a value you set before training begins
#
# Replace each ___ with the correct string

labels = {
    'decision tree max_depth':        ___,   # YOUR CODE
    'linear regression coefficient':  ___,   # YOUR CODE
    'KNN n_neighbors':                ___,   # YOUR CODE
    'neural network weight':          ___,   # YOUR CODE
    'learning rate':                  ___,   # YOUR CODE
}

print("Your labels:")
for item, label in labels.items():
    print(f"  {item:<38} \u2192 {label}")

# --- checks ---
assert labels['decision tree max_depth'] == 'hyperparameter', \
    "max_depth is chosen before training — the model does not learn it from data"
assert labels['linear regression coefficient'] == 'parameter', \
    "Coefficients are calculated during .fit() — the model learns them from data"
assert labels['KNN n_neighbors'] == 'hyperparameter', \
    "n_neighbors is set by you before training begins"
assert labels['neural network weight'] == 'parameter', \
    "Weights are updated during backpropagation — the model learns them"
assert labels['learning rate'] == 'hyperparameter', \
    "Learning rate is set before training — the optimizer uses it, but the model does not learn it"
print("\u2713 B2 complete!")

# %% [markdown]
# ### B3 — Matrix multiplication as prediction
#
# Every linear model — linear regression, logistic regression, and every layer of a neural network — makes predictions through one operation: matrix multiplication. Once you recognize this pattern, you will see it in every algorithm.

# %%
# B3 — Complete the forward pass using matrix multiplication
#
# A linear model predicts: y_hat = X @ coefficients + intercept
#
#   X            — feature matrix (rows = samples, columns = features)
#   coefficients — one learned weight per feature
#   intercept    — bias term (the y-intercept)

X_small = np.array([
    [1.0, 2.0],   # sample 0: feature_1=1.0, feature_2=2.0
    [3.0, 4.0],   # sample 1
    [5.0, 6.0],   # sample 2
])

coefficients = np.array([0.5, 1.0])   # one weight per feature
intercept    = 2.0

# Predict for all 3 samples at once
# Hint: use the @ operator for matrix multiplication, then add the intercept
y_hat = ___   # YOUR CODE — one line

print("Predicted values:")
for i, pred in enumerate(y_hat):
    print(f"  Sample {i}: {pred:.2f}")

# --- checks ---
assert y_hat is not None, "Compute y_hat using @ and +"
assert y_hat.shape == (3,), \
    f"y_hat should have shape (3,) — one prediction per sample. Got {y_hat.shape}"
assert abs(y_hat[0] - 4.5) < 1e-6, \
    "Sample 0: 1.0*0.5 + 2.0*1.0 + 2.0 = 4.5"
assert abs(y_hat[1] - 7.5) < 1e-6, \
    "Sample 1: 3.0*0.5 + 4.0*1.0 + 2.0 = 7.5"
assert abs(y_hat[2] - 10.5) < 1e-6, \
    "Sample 2: 5.0*0.5 + 6.0*1.0 + 2.0 = 10.5"
print("\u2713 B3 complete!")

# %% [markdown]
# ---
# ## Section C — Applied Problem: Classifying Real-World ML Scenarios
#
# Four different organizations have approached a data science team for help. For each scenario, you need to decide two things:
#
# 1. **Problem type** — is the output a continuous number (regression) or a category (classification)?
# 2. **Interpretability requirement** — how important is it that the model can explain its decisions?
#
# These two decisions shape every other choice you make: which algorithm to try first, how to evaluate the model, and what trade-offs are acceptable.
#
# | Scenario | Description |
# |---|---|
# | `medical_diagnosis` | A hospital predicts whether a patient has early-stage cancer based on lab results. Doctors must explain every decision to the patient and to regulators. |
# | `movie_recommendations` | A streaming platform predicts how many stars a user will give to a film they have not yet watched. Speed matters more than explainability. |
# | `loan_approval` | A bank approves or denies personal loans. Applicants who are denied have a legal right to know why. |
# | `spam_detection` | An email service classifies each incoming message as spam or not spam. Users rarely need a reason — they just want accuracy and speed. |

# %%
# Section C — Fill in problem_type and interpretability for each scenario
#
# 'problem_type'     → 'regression' or 'classification'
# 'interpretability' → 'high', 'medium', or 'low'

scenario_answers = {
    'medical_diagnosis':     {'problem_type': ___, 'interpretability': ___},
    'movie_recommendations': {'problem_type': ___, 'interpretability': ___},
    'loan_approval':         {'problem_type': ___, 'interpretability': ___},
    'spam_detection':        {'problem_type': ___, 'interpretability': ___},
}

# --- Section C checks ---
valid_types  = {'regression', 'classification'}
valid_interp = {'high', 'medium', 'low'}

for scenario, answers in scenario_answers.items():
    assert answers['problem_type'] in valid_types, \
        f"'{scenario}' problem_type must be 'regression' or 'classification' — got '{answers['problem_type']}'"
    assert answers['interpretability'] in valid_interp, \
        f"'{scenario}' interpretability must be 'high', 'medium', or 'low' — got '{answers['interpretability']}'"

assert scenario_answers['medical_diagnosis']['problem_type'] == 'classification', \
    "Medical diagnosis predicts a category (cancer / no cancer) — that is classification"
assert scenario_answers['medical_diagnosis']['interpretability'] == 'high', \
    "Doctors must explain every decision — interpretability is a requirement, not a preference"
assert scenario_answers['movie_recommendations']['problem_type'] == 'regression', \
    "Predicting a star rating (a number from 1.0 to 5.0) is a regression problem"
assert scenario_answers['loan_approval']['problem_type'] == 'classification', \
    "Approve or deny is a binary classification decision"
assert scenario_answers['loan_approval']['interpretability'] == 'high', \
    "Denied applicants have a legal right to an explanation — interpretability is required"
assert scenario_answers['spam_detection']['problem_type'] == 'classification', \
    "Spam or not spam is a binary classification decision"

print("\u2713 Section C complete!")
print()
for scenario, answers in scenario_answers.items():
    print(f"  {scenario:<26}  type={answers['problem_type']:<16}  interpretability={answers['interpretability']}")

# %% [markdown]
# ---
#
# ## Section D — Reflection
#
# These questions are for reflection. Edit the markdown cells below each question to write your response. There are no wrong answers — we are looking for thoughtful engagement with what you have learned. Your instructor may review these.

# %% [markdown]
# **Question D1**
#
# The interpretability working session showed that in regulated industries, some algorithms become unavailable choices regardless of accuracy.
#
# Describe a real-world situation where you would deliberately choose a less accurate but more interpretable model. What trade-off are you accepting, and why is it worth it?

# %% [markdown]
# *Your response here...*

# %% [markdown]
# **Question D2**
#
# B2 had you label five items as either `'parameter'` or `'hyperparameter'`.
#
# In your own words, explain the difference between the two. Give one concrete example of each from any of today’s working sessions.

# %% [markdown]
# *Your response here...*

# %% [markdown]
# **Question D3**
#
# The test set generalization working session simulated a Kaggle competition where a gap opened between public and private leaderboard scores as the number of submissions increased.
#
# In your own words, explain the mechanism that causes this gap. What is the data scientist doing — even unintentionally — that inflates the public score relative to the true private score?

# %% [markdown]
# *Your response here...*
